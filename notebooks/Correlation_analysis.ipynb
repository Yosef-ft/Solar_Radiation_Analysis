# %% [markdown]
# ## Solar Radiation Analysis

# %% [markdown]
# #### IMPORTING IMPORTANT LIBRARIES

# %%
import datetime

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use('dark_background')

# %%
import sys
import os

sys.path.append(os.path.abspath('../scripts'))

from utils import load_dataset
from plotting import corr_wind_solar
from plotting import corr_analysis

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### IMPORTING DATASET

# %%
benin, sierra, togo = load_dataset()

# %% [markdown]
# #### Correlation Analysis

# %% [markdown]
# ##### correlations between solar radiation components and temperature measures

# %%
corr_analysis(benin)

# %%
corr_analysis(sierra)

# %%
corr_analysis(togo)

# %% [markdown]
# **Observations**
# - `GHI` is highly correlated with `TModA`
# - `DHI` is highly correlated with `GHI`
# - `DNI` is highly correlated with `GHI`
# - `TModA` is highly correlated with `TModB`
# - `TmodB` is highly correlated with `TModA`

# %% [markdown]
# #### Relationship between wind conditions and solar irradiance

# %%
corr_wind_solar(benin)

# %%
corr_wind_solar(sierra)

# %%
corr_wind_solar(togo)
